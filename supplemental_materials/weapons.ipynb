# %% [markdown]
# <a href="https://colab.research.google.com/github/ds-20195/notebooks/blob/main/supplemental_materials/weapons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q geopandas networkx

# %%
# !pip install "git+https://github.com/DS-20195/notebooks#egg=ds20195&subdirectory=lib"
# Out:
# Collecting ds20195
#   Cloning https://github.com/DS-20195/notebooks to /tmp/pip-install-jyqav5_o/ds20195_b7faf89f1086452f854f385deff62b32
#   Running command git clone --filter=blob:none --quiet https://github.com/DS-20195/notebooks /tmp/pip-install-jyqav5_o/ds20195_b7faf89f1086452f854f385deff62b32
#   Resolved https://github.com/DS-20195/notebooks to commit 39bbf9b7bc787ebab95efbdefa3792fdc63f3320
#   Preparing metadata (setup.py) ... done
# Collecting census>=0.8.19 (from ds20195)
#   Downloading census-0.8.26-py3-none-any.whl.metadata (8.2 kB)
# Collecting us>=2.0.2 (from ds20195)
#   Downloading us-3.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from ds20195) (2.2.2)
# Collecting gspread_pandas>=3.3.0 (from ds20195)
#   Downloading gspread_pandas-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ds20195) (4.67.3)
# Requirement already satisfied: requests>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from census>=0.8.19->ds20195) (2.32.4)
# Collecting gspread<6,>=5.0.0 (from gspread_pandas>=3.3.0->ds20195)
#   Downloading gspread-5.12.4-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from gspread_pandas>=3.3.0->ds20195) (4.4.2)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (from gspread_pandas>=3.3.0->ds20195) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gspread_pandas>=3.3.0->ds20195) (1.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->ds20195) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->ds20195) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->ds20195) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->ds20195) (2026.1)
# Collecting jellyfish (from us>=2.0.2->ds20195)
#   Downloading jellyfish-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (642 bytes)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth->gspread_pandas>=3.3.0->ds20195) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth->gspread_pandas>=3.3.0->ds20195) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gspread_pandas>=3.3.0->ds20195) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.2->ds20195) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=1.1.0->census>=0.8.19->ds20195) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=1.1.0->census>=0.8.19->ds20195) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=1.1.0->census>=0.8.19->ds20195) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=1.1.0->census>=0.8.19->ds20195) (2026.4.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth->gspread_pandas>=3.3.0->ds20195) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gspread_pandas>=3.3.0->ds20195) (3.3.1)
# Downloading census-0.8.26-py3-none-any.whl (11 kB)
# Downloading gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Downloading us-3.2.0-py3-none-any.whl (13 kB)
# Downloading gspread-5.12.4-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 1.6 MB/s eta 0:00:00
# Downloading jellyfish-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 9.5 MB/s eta 0:00:00
# Building wheels for collected packages: ds20195
#   Building wheel for ds20195 (setup.py) ... done
#   Created wheel for ds20195: filename=ds20195-0.0.1-py3-none-any.whl size=3688 sha256=295bcd85ba0de32a38c364cb60a4e5d57f2b8373973b01e5c52c33899f10ffbd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wlyzxgw8/wheels/24/47/8f/2780756f1cf00353089b7ee711e2b4c944ef371f5c37082c7d
# Successfully built ds20195
# Installing collected packages: jellyfish, us, census, gspread, gspread_pandas, ds20195
#   Attempting uninstall: gspread
#     Found existing installation: gspread 6.2.1
#     Uninstalling gspread-6.2.1:
#       Successfully uninstalled gspread-6.2.1
# Successfully installed census-0.8.26 ds20195-0.0.1 gspread-5.12.4 gspread_pandas-3.3.0 jellyfish-1.2.1 us-3.2.0

# %%
# %config InlineBackend.figure_formats = ["svg"]
import base64
import io
import json
import requests

import pandas as pd; pd.set_option('display.max_rows', 500)
import geopandas as gpd
import matplotlib.pyplot as plt
import networkx as nx

from shapely import Point
from ds20195 import google_sheets_credentials, generate_flow_sheet

# %% [markdown]
# # Week 5: Graphs, flows, and arms

# %% [markdown]
# ### Fetching SIPRI flow data
#
# This is a case study in real-world data munging.  There is extensive pre-processing to do to make the data useable.  We've chosen to show it to you in this notebook so that you get a realistic sense of the data challenges of working with a new dataset by reading through the notebook.  (Of course, you can also just click through it and everything should work.)

# %% [markdown]
# We're going to be working with a dataset from SIPRI (the Stockholm International Peace Research Institute) that tracks how arms and weaponry move around the world.
#
# They have created a unit of weaponry called TIV ("trend indicator value"), which is an attempt to measure comparable amounts of **military capability**. It's some mix of cost and lethality that is designed to make it possible to compare arms flows across type and time.
#
# For more on TIV, see the SIPRI fact sheet ["Measuring International Arms Transfers"](https://www.sipri.org/sites/default/files/files/FS/SIPRIFS1212.pdf).

# %% [markdown]
# SIPRI doesn't intend for users to grab their full dataset all at once, but we've figured out how to pull the whole CSV without any filters.  This might take a minute or more to run.  If it times out, try it again!

# %%
raw_data = requests.post(
    "https://atbackend.sipri.org/api/p/trades/trade-register-csv/",
    json={"filters": []},
).json()

# %% [markdown]
# Next, it turns out to be encoded in base 64, and we have to convert it to a more standard format.  Base 64 is a pretty nonstandard format, often used because it can encompass special characters, so it's important to notice the need to translate it or subsequent manipulations won't work as expected.
#
# When you run the next cell, we'll examine the first 15 lines of the decoded file, which turns out to be a text header that needs to be chopped off the CSV for the rest of our work.  So we split at the carriage return (`split("\n")`) before continuing.

# %%
csv_lines = base64.b64decode(raw_data["bytes"]).decode("iso-8859-1").split("\n")
csv_lines[:15]
# Out:
# ["Transfers of major conventional arms from All countries  to All countries . Deals with deliveries made for the year range 'Not specified' to 'Not specified' ",
#  "A '?' in a column indicates uncertain data. The 'Number delivered' and the 'Year(s) of deliveries' refer only to deliveries in the selected year(s).",
#  "An empty field for 'Number ordered' indicates that data is not yet available.",
#  'SIPRI trend-indicator values (TIVs) are in millions.',
#  "An empty field for 'SIPRI TIV for total order' indicates that data (on the number ordered and/or the TIV per unit) is not available.",
#  "A '0' for 'SIPRI TIV of delivered weapons' indicates that the volume of deliveries is between 0 and 0.5 million SIPRI TIV; and an empty field indicates that no deliveries have been identified.",
#  'Figures may not add up to stated totals due to the conventions of rounding.',
#  'For the method used for the SIPRI TIV and explanations of the conventions; abbreviations and acronyms see <https://www.sipri.org/databases/armstransfers/sources-and-methods>.',
#  '',
#  'Source: SIPRI Arms Transfers Database (c) SIPRI.',
#  'Data generated: 12 May 2026 6:11:07 AM',
#  'Recipient,Supplier,Year of order, ,Number ordered, ,Weapon designation,Weapon description,Number delivered, ,Year(s) of delivery,status,Comments,SIPRI TIV per unit,SIPRI TIV for total order,SIPRI TIV of delivered weapons',
#  'Afghanistan,Russia,2010,?,6,?,Mi-17,transport helicopter,6,,2011,Second hand,Probably second-hand; Mi-17V1 version; bought via and financed by USA; incl for training of Afghan crews and US instructors in USA,2.9,17.4,17.4',
#  'Afghanistan,Russia,2004,?,4,,Mi-17,transport helicopter,4,?,2005,Second hand,Second-hand; aid; Mi-8MTV version,2.9,11.6,11.6',
#  'Afghanistan,Soviet Union,1960,?,50,?,BM-13 132mm,multiple rocket launcher,50,?,1960; 1961,Second hand,Second-hand,0.08,4,4']

# %%
first_line_index = next(idx for idx, line in enumerate(csv_lines) if line.startswith("Recipient,"))
first_line_index
# Out:
# 11

# %% [markdown]
# Let's make the dataframe!  It's got a huge amount of information about the weapons, when ordered, whether new or second-hand, and comments about the conflict context.

# %%
arms_df = pd.read_csv(io.StringIO("\n".join(csv_lines[first_line_index:])))
arms_df.to_csv("fulldata.csv")
arms_df
# Out:
#          Recipient      Supplier  Year of order     Number ordered   .1  \
# 0      Afghanistan        Russia           2010  ?             6.0    ?
# 1      Afghanistan        Russia           2004  ?             4.0  NaN
# 2      Afghanistan  Soviet Union           1960  ?            50.0    ?
# 3      Afghanistan  Soviet Union           1978  ?           500.0    ?
# 4      Afghanistan  Soviet Union           1987  ?            40.0    ?
# ...            ...           ...            ... ..             ...  ...
# 29911     Zimbabwe         China           1984  ?             2.0  NaN
# 29912     Zimbabwe         China           1990  ?             2.0  NaN
# 29913     Zimbabwe         Italy           1967  ?            20.0    ?
# 29914     Zimbabwe        France           1977  ?             3.0  NaN
# 29915     Zimbabwe        Russia           1998  ?             6.0  NaN
#
#       Weapon designation        Weapon description  Number delivered   .2  \
# 0                  Mi-17      transport helicopter                 6  NaN
# 1                  Mi-17      transport helicopter                 4    ?
# 2            BM-13 132mm  multiple rocket launcher                50    ?
# 3                   T-55                      tank               500    ?
# 4               MiG-21MF          fighter aircraft                40    ?
# ...                  ...                       ...               ...  ...
# 29911               FT-5  (armed) trainer aircraft                 2  NaN
# 29912                J-7          fighter aircraft                 2  NaN
# 29913     Model-56 105mm                 towed gun                20    ?
# 29914     Cessna-337/O-2            light aircraft                 3  NaN
# 29915             Mi-24P         combat helicopter                 6  NaN
#
#                                      Year(s) of delivery       status  \
# 0                                                   2011  Second hand
# 1                                                   2005  Second hand
# 2                                             1960; 1961  Second hand
# 3      1979; 1980; 1981; 1982; 1983; 1984; 1985; 1986...  Second hand
# 4                                 1987; 1988; 1989; 1990  Second hand
# ...                                                  ...          ...
# 29911                                               1986  Second hand
# 29912                                               1991          New
# 29913                                               1967          New
# 29914                                               1977          New
# 29915                                               1999  Second hand
#
#                                                 Comments  SIPRI TIV per unit  \
# 0      Probably second-hand; Mi-17V1 version; bought ...                2.90
# 1                      Second-hand; aid; Mi-8MTV version                2.90
# 2                                            Second-hand                0.08
# 3                                       Second-hand; aid                0.50
# 4               Second-hand; probably incl some MiG-21UM                4.28
# ...                                                  ...                 ...
# 29911                               Probably Second-hand                1.50
# 29912                                     FT-7BZ version                9.00
# 29913                                 Supplier uncertain                0.45
# 29914                                                NaN                0.35
# 29915  Second-hand; bought for use in DRC against reb...                3.60
#
#        SIPRI TIV for total order  SIPRI TIV of delivered weapons
# 0                          17.40                           17.40
# 1                          11.60                           11.60
# 2                           4.00                            4.00
# 3                         250.00                          250.00
# 4                         171.20                          171.20
# ...                          ...                             ...
# 29911                       3.00                            3.00
# 29912                      18.00                           18.00
# 29913                       9.00                            9.00
# 29914                       1.05                            1.05
# 29915                      21.60                           21.60
#
# [29916 rows x 16 columns]

# %%
arms_df.groupby(["Recipient", "Supplier", "Year of order"]).count()
# Out:
#                                                           Number ordered   .1  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988           0               1    1
# Afghanistan          Belarus            2018           0               1    0
#                      Bosnia-Herzegovina 2009           0               1    0
#                                         2012           1               1    1
#                      Brazil             2013           0               1    0
# ...                                                   ..             ...  ...
# unknown recipient(s) United States      1990           1               1    1
#                                         1995           0               1    0
#                                         2010           0               1    1
#                                         2018           2               2    2
#                                         2025           0               0    0
#
#                                                        Weapon designation  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                            1
# Afghanistan          Belarus            2018                            1
#                      Bosnia-Herzegovina 2009                            1
#                                         2012                            1
#                      Brazil             2013                            1
# ...                                                                   ...
# unknown recipient(s) United States      1990                            1
#                                         1995                            1
#                                         2010                            1
#                                         2018                            2
#                                         2025                            1
#
#                                                        Weapon description  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                            1
# Afghanistan          Belarus            2018                            1
#                      Bosnia-Herzegovina 2009                            1
#                                         2012                            1
#                      Brazil             2013                            1
# ...                                                                   ...
# unknown recipient(s) United States      1990                            1
#                                         1995                            1
#                                         2010                            1
#                                         2018                            2
#                                         2025                            1
#
#                                                        Number delivered   .2  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                          1    1
# Afghanistan          Belarus            2018                          1    0
#                      Bosnia-Herzegovina 2009                          1    1
#                                         2012                          1    0
#                      Brazil             2013                          1    1
# ...                                                                 ...  ...
# unknown recipient(s) United States      1990                          1    1
#                                         1995                          1    0
#                                         2010                          1    1
#                                         2018                          2    2
#                                         2025                          1    0
#
#                                                        Year(s) of delivery  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                             1
# Afghanistan          Belarus            2018                             1
#                      Bosnia-Herzegovina 2009                             1
#                                         2012                             1
#                      Brazil             2013                             1
# ...                                                                    ...
# unknown recipient(s) United States      1990                             1
#                                         1995                             1
#                                         2010                             1
#                                         2018                             2
#                                         2025                             0
#
#                                                        status  Comments  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                1         0
# Afghanistan          Belarus            2018                1         1
#                      Bosnia-Herzegovina 2009                1         1
#                                         2012                1         1
#                      Brazil             2013                1         1
# ...                                                       ...       ...
# unknown recipient(s) United States      1990                1         1
#                                         1995                1         1
#                                         2010                1         1
#                                         2018                2         0
#                                         2025                1         0
#
#                                                        SIPRI TIV per unit  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                            1
# Afghanistan          Belarus            2018                            1
#                      Bosnia-Herzegovina 2009                            1
#                                         2012                            1
#                      Brazil             2013                            1
# ...                                                                   ...
# unknown recipient(s) United States      1990                            1
#                                         1995                            1
#                                         2010                            1
#                                         2018                            2
#                                         2025                            1
#
#                                                        SIPRI TIV for total order  \
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                                   1
# Afghanistan          Belarus            2018                                   1
#                      Bosnia-Herzegovina 2009                                   1
#                                         2012                                   1
#                      Brazil             2013                                   1
# ...                                                                          ...
# unknown recipient(s) United States      1990                                   1
#                                         1995                                   1
#                                         2010                                   1
#                                         2018                                   2
#                                         2025                                   1
#
#                                                        SIPRI TIV of delivered weapons
# Recipient            Supplier           Year of order
# ANC (South Africa)*  Soviet Union       1988                                        1
# Afghanistan          Belarus            2018                                        1
#                      Bosnia-Herzegovina 2009                                        1
#                                         2012                                        1
#                      Brazil             2013                                        1
# ...                                                                               ...
# unknown recipient(s) United States      1990                                        1
#                                         1995                                        1
#                                         2010                                        1
#                                         2018                                        2
#                                         2025                                        1
#
# [16104 rows x 13 columns]

# %% [markdown]
# We can narrow down what we're looking at.  The next cell lets you toggle between looking for (a) [Mi-17s](https://en.wikipedia.org/wiki/Mil_Mi-17) that do not come from Russia/USSR, or (b) second-hand weapons.  Try it both ways.

# %%
arms_df[(arms_df["Weapon designation"] == "Mi-17") & (arms_df["Supplier"] != "Russia") & (arms_df["Supplier"] != "Soviet Union")]
# arms_df[arms_df["status"] == "Second hand"]
# Out:
#              Recipient             Supplier  Year of order       \
# 47         Afghanistan              Czechia           2007  NaN
# 50         Afghanistan             Slovakia           2007  NaN
# 52         Afghanistan  unknown supplier(s)           2007    ?
# 104        Afghanistan       United Kingdom           2009  NaN
# 151    African Union**  unknown supplier(s)           2004  NaN
# 702             Angola              Czechia           2006    ?
# 753             Angola  unknown supplier(s)           1993    ?
# 3756          Cambodia              Ukraine           1997  NaN
# 3770          Cambodia              Ukraine           1994    ?
# 4065            Canada  unknown supplier(s)           2010  NaN
# 4297              Chad              Ukraine           2000    ?
# 5350             Congo  unknown supplier(s)           2019    ?
# 5351             Congo           Costa Rica           2009    ?
# 5385        Costa Rica            Nicaragua           1992    ?
# 5481     Cote d'Ivoire  unknown supplier(s)           2023    ?
# 8623           Georgia              Ukraine           2004    ?
# 9853            Guinea              Ukraine           2001    ?
# 14549       Kyrgyzstan           Kazakhstan           2003  NaN
# 14690           Latvia  unknown supplier(s)           2001    ?
# 14716           Latvia  unknown supplier(s)           1999    ?
# 14927          Liberia  unknown supplier(s)           2000    ?
# 16095           Mexico             Colombia           2002  NaN
# 16653       Mozambique  unknown supplier(s)           2020    ?
# 16946            Nepal              Belarus           2002  NaN
# 16975            Nepal              Ukraine           2002    ?
# 16987            Nepal           Kazakhstan           1999    ?
# 17632            Niger  unknown supplier(s)           2003    ?
# 18125  North Macedonia              Ukraine           2000    ?
# 19038         Pakistan        United States           2009  NaN
# 19700             Peru            Nicaragua           1992  NaN
# 19703             Peru            Nicaragua           1992  NaN
# 20402           Poland            Lithuania           2001    ?
# 21939           Serbia              Ukraine           1998  NaN
# 22001     Sierra Leone         South Africa           1995    ?
# 22011     Sierra Leone              Ukraine           1997    ?
# 22012     Sierra Leone              Ukraine           1994    ?
# 24048        Sri Lanka              Ukraine           1995    ?
# 27170          Ukraine        United States           2022    ?
# 27237          Ukraine              Croatia           2022  NaN
# 27413          Ukraine            Lithuania           2022    ?
# 27431          Ukraine               Latvia           2022  NaN
# 27529          Ukraine             Slovakia           2022  NaN
# 28191   United Kingdom              Moldova           2011    ?
# 28554    United States  unknown supplier(s)           1992    ?
# 28555    United States  unknown supplier(s)           2001    ?
# 28575    United States             Bulgaria           2002  NaN
#
#        Number ordered   .1 Weapon designation    Weapon description  \
# 47                6.0  NaN              Mi-17  transport helicopter
# 50                3.0    ?              Mi-17  transport helicopter
# 52                6.0  NaN              Mi-17  transport helicopter
# 104               2.0  NaN              Mi-17  transport helicopter
# 151              15.0  NaN              Mi-17  transport helicopter
# 702               2.0  NaN              Mi-17  transport helicopter
# 753               7.0    ?              Mi-17  transport helicopter
# 3756              2.0  NaN              Mi-17  transport helicopter
# 3770              4.0    ?              Mi-17  transport helicopter
# 4065              3.0    ?              Mi-17  transport helicopter
# 4297              2.0  NaN              Mi-17  transport helicopter
# 5350              1.0    ?              Mi-17  transport helicopter
# 5351              1.0  NaN              Mi-17  transport helicopter
# 5385              1.0  NaN              Mi-17  transport helicopter
# 5481              2.0  NaN              Mi-17  transport helicopter
# 8623              2.0    ?              Mi-17  transport helicopter
# 9853              2.0  NaN              Mi-17  transport helicopter
# 14549             2.0  NaN              Mi-17  transport helicopter
# 14690             1.0  NaN              Mi-17  transport helicopter
# 14716             1.0  NaN              Mi-17  transport helicopter
# 14927             3.0    ?              Mi-17  transport helicopter
# 16095             2.0  NaN              Mi-17  transport helicopter
# 16653             3.0    ?              Mi-17  transport helicopter
# 16946             2.0  NaN              Mi-17  transport helicopter
# 16975             2.0    ?              Mi-17  transport helicopter
# 16987             2.0  NaN              Mi-17  transport helicopter
# 17632             2.0    ?              Mi-17  transport helicopter
# 18125             4.0  NaN              Mi-17  transport helicopter
# 19038            10.0  NaN              Mi-17  transport helicopter
# 19700             2.0  NaN              Mi-17  transport helicopter
# 19703            13.0  NaN              Mi-17  transport helicopter
# 20402             1.0  NaN              Mi-17  transport helicopter
# 21939             2.0  NaN              Mi-17  transport helicopter
# 22001             2.0  NaN              Mi-17  transport helicopter
# 22011             2.0  NaN              Mi-17  transport helicopter
# 22012             2.0    ?              Mi-17  transport helicopter
# 24048             3.0  NaN              Mi-17  transport helicopter
# 27170            20.0  NaN              Mi-17  transport helicopter
# 27237            11.0  NaN              Mi-17  transport helicopter
# 27413             2.0  NaN              Mi-17  transport helicopter
# 27431             4.0  NaN              Mi-17  transport helicopter
# 27529             4.0  NaN              Mi-17  transport helicopter
# 28191             2.0  NaN              Mi-17  transport helicopter
# 28554             7.0    ?              Mi-17  transport helicopter
# 28555             3.0    ?              Mi-17  transport helicopter
# 28575             1.0  NaN              Mi-17  transport helicopter
#
#        Number delivered   .2 Year(s) of delivery                      status  \
# 47                    6  NaN          2007; 2008  Second hand but modernized
# 50                    3    ?                2008                 Second hand
# 52                    6  NaN                2008                 Second hand
# 104                   2  NaN                2010                 Second hand
# 151                  15    ?                2005                 Second hand
# 702                   2  NaN                2007                 Second hand
# 753                   7    ?                1993                 Second hand
# 3756                  2  NaN                1997                 Second hand
# 3770                  4    ?                1994                 Second hand
# 4065                  3    ?                2010                         New
# 4297                  2    ?                2001                 Second hand
# 5350                  1  NaN                2019                 Second hand
# 5351                  1  NaN                2009                 Second hand
# 5385                  1  NaN                1993                 Second hand
# 5481                  0  NaN                 NaN                 Second hand
# 8623                  2  NaN                2005                 Second hand
# 9853                  2  NaN                2001                 Second hand
# 14549                 2  NaN                2004                 Second hand
# 14690                 1  NaN                2002                 Second hand
# 14716                 1  NaN                2000                 Second hand
# 14927                 3    ?                2000                 Second hand
# 16095                 2  NaN                2002                 Second hand
# 16653                 3    ?                2021                 Second hand
# 16946                 2  NaN                2003                 Second hand
# 16975                 2    ?                2002                 Second hand
# 16987                 2  NaN                2001  Second hand but modernized
# 17632                 2    ?                2003                 Second hand
# 18125                 4  NaN                2001                 Second hand
# 19038                10  NaN                2009                 Second hand
# 19700                 2  NaN                1993                 Second hand
# 19703                13  NaN          1992; 1993                 Second hand
# 20402                 1  NaN                2002                 Second hand
# 21939                 2  NaN                1998                 Second hand
# 22001                 2  NaN                1995                 Second hand
# 22011                 2  NaN                1999                 Second hand
# 22012                 2    ?                1994                 Second hand
# 24048                 3  NaN                1996                 Second hand
# 27170                20  NaN          2022; 2023                 Second hand
# 27237                11  NaN                2023                 Second hand
# 27413                 2  NaN                2023                 Second hand
# 27431                 4    ?          2022; 2023                 Second hand
# 27529                 4  NaN                2022                 Second hand
# 28191                 2  NaN                2011                 Second hand
# 28554                 7    ?                1993                 Second hand
# 28555                 3  NaN          2001; 2002                 Second hand
# 28575                 1  NaN                2002                 Second hand
#
#                                                 Comments  SIPRI TIV per unit  \
# 47     Second-hand but modernized before delivery; ai...                4.79
# 50                                      Second-hand; aid                2.90
# 52     Probably second-hand; financed by United Arab ...                2.90
# 104    Second-hand; bought by United Kingdom for 'Pro...                2.90
# 151    Leased from and operated by civilian company f...                2.90
# 702                           Second-hand; Mi-17 version                2.90
# 753                Second-hand; supplier possibly Russia                2.90
# 3756   Second-hand; $1.3 m deal; probably illegally e...                2.90
# 3770   Second-hand; probably incl 2 Mi-8 and 2 Mi-17 ...                2.90
# 4065   Possibly second-hand; lease for use in Afghani...                7.25
# 4297                                         Second-hand                2.90
# 5350              Probably second-hand; Mi-17-1V version                2.90
# 5351                                         Second-hand                2.90
# 5385                 Second-hand; aid; for border police                2.90
# 5481                         Secodn-hand; Mi-171 version                2.90
# 8623       Second-handrainian; Mi-8MT or Mi-8MTV version                2.90
# 9853                                         Second-hand                2.90
# 14549  Ex-Kazakh; $3.5 m deal (financed by USA); Mi-8...                2.90
# 14690  Probably second-hand; Mi-8MTV-1 version; incl ...                2.90
# 14716  Probably second-hand; Mi-8MTV-1 version; incl ...                2.90
# 14927         Probably second-hand; flown by mercenaries                2.90
# 16095   Second-hand; $8.2 m deal; armed Mi-17-V1 version                2.90
# 16653  Second-hand; Mi-17-1V version; sold via South ...                2.90
# 16946  Second-hand; financed by UK for police use aga...                2.90
# 16975                                        Second-hand                2.90
# 16987  Second-hand; $5.8-7 m deal; modernized before ...                4.79
# 17632                               Probably second-hand                2.90
# 18125  Second-hand; armed Mi-8MT version; for use aga...                2.90
# 19038  Second-hand; Mi-17 version; incl 6 on 5-year l...                2.90
# 19700                                        Second-hand                2.90
# 19703  Second-hand; 1 more for spare parts; part of $...                2.90
# 20402  Second-hand; Mi-8MTV-1 version; partly finance...                2.90
# 21939  Second-hand; Mi-17 version; incl 1 armed Mi-17...                2.90
# 22001  Second-hand; bought by South African mercenary...                2.90
# 22011                 Second-hand; designation uncertain                2.90
# 22012                                        Second-hand                2.90
# 24048                                        Second-hand                2.90
# 27170  Second-hand; aid after 2022 Russian invasion o...                2.90
# 27237  Second-hand; aid after 2022 Russian invasion o...                2.90
# 27413  Second-hand; aid after 2022 Russian invasion o...                2.90
# 27431  Second-hand; aid after 2022 Russian invasion o...                2.90
# 27529  Second-hand; financed by EU aid after 2022 Rus...                2.90
# 28191  Second-hand; Mi-171 version; lease via Canadia...                2.90
# 28554  Second-hand; Mi-8 version; possibly former GDR...                2.90
# 28555  Second-hand; supplier could be former Soviet C...                2.90
# 28575                                        Second-hand                2.90
#
#        SIPRI TIV for total order  SIPRI TIV of delivered weapons
# 47                         28.71                           28.71
# 50                          8.70                            8.70
# 52                         17.40                           17.40
# 104                         5.80                            5.80
# 151                        43.50                           43.50
# 702                         5.80                            5.80
# 753                        20.30                           20.30
# 3756                        5.80                            5.80
# 3770                       11.60                           11.60
# 4065                       21.75                           21.75
# 4297                        5.80                            5.80
# 5350                        2.90                            2.90
# 5351                        2.90                            2.90
# 5385                        2.90                            2.90
# 5481                        5.80                            0.00
# 8623                        5.80                            5.80
# 9853                        5.80                            5.80
# 14549                       5.80                            5.80
# 14690                       2.90                            2.90
# 14716                       2.90                            2.90
# 14927                       8.70                            8.70
# 16095                       5.80                            5.80
# 16653                       8.70                            8.70
# 16946                       5.80                            5.80
# 16975                       5.80                            5.80
# 16987                       9.57                            9.57
# 17632                       5.80                            5.80
# 18125                      11.60                           11.60
# 19038                      29.00                           29.00
# 19700                       5.80                            5.80
# 19703                      37.70                           37.70
# 20402                       2.90                            2.90
# 21939                       5.80                            5.80
# 22001                       5.80                            5.80
# 22011                       5.80                            5.80
# 22012                       5.80                            5.80
# 24048                       8.70                            8.70
# 27170                      58.00                           58.00
# 27237                      31.90                           31.90
# 27413                       5.80                            5.80
# 27431                      11.60                           11.60
# 27529                      11.60                           11.60
# 28191                       5.80                            5.80
# 28554                      20.30                           20.30
# 28555                       8.70                            8.70
# 28575                       2.90                            2.90

# %% [markdown]
# What other statuses are possible?

# %%
arms_df["status"].unique()
# Out:
# array(['Second hand', 'New', 'Second hand but modernized'], dtype=object)

# %%
arms_df["Weapon designation"].value_counts()
# Out:
# Weapon designation
# aircraft engine    439
# ship engine        397
# vehicle engine     283
# Mi-17              241
# M-113              227
#                   ...
# KS-30 130mm          1
# RGS-9316             1
# Wusung               1
# Khukri               1
# SON-30               1
# Name: count, Length: 4248, dtype: int64

# %% [markdown]
# # Mapping transfers
#
#
# Visualizing the SIPRI dataset presents several problems:
#
# * Recipients and suppliers are _usually_ countries, but this does not always hold. Notice that the dataset includes non-state actors (such as the [Houthi rebels](https://en.wikipedia.org/wiki/Houthis) or the [Mujahideen](https://en.wikipedia.org/wiki/Afghan_mujahideen)).  We will need one lat/long location per actor, so we'll try to find an appropriate capital city.
# * This dataset goes back to the 1940s, so it references countries that no longer exist (such as [Biafra](https://en.wikipedia.org/wiki/Biafra) and [Yugoslavia](https://en.wikipedia.org/wiki/Yugoslavia)).
# * There is some variability in names. For instance, "Ivory Coast" and "Cote d'Ivoire" are two different names for the same country.
#
# For visualization purposes, we'll map these special cases to the nearest equivalent contemporary states. For instance, we'll map South Vietnam to Vietnam; Saigon (the former capital of South Vietnam) is now Ho Chi Minh City (the current capital of Vietnam). We'll exclude flows to or from entities that do not clearly correspond to a single region (for instance, the United Nations).

# %% [markdown]
# The following dictionary associating SIPRI states to modern states was made by hand and represents a lot of labor!  You should at least glance through it to get a sense of some of the nitty-gritty involved here.  Note the comments at the end about non-obvious decisions (a good practice when cleaning data, so you'll know what you were thinking later on!) and the explicit list of exceptions.

# %%
capitals_map = {
    "ANC (South Africa)*": "South Africa",
    "Anti-Castro rebels (Cuba)*": "Cuba",
    "Amal (Lebanon)*": "Lebanon",
    "Armas (Guatemala)*": "Guatemala",
    "Contras (Nicaragua)*": "Nicaragua",
    "Darfur rebels (Sudan)*": "Sudan",
    "ELF (Ethiopia)*": "Ethiopia",
    "EPLF (Ethiopia)*": "Ethiopia",
    "FRELIMO (Portugal)*": "Portugal",
    "Haiti rebels*": "Haiti",
    "Hezbollah (Lebanon)*": "Lebanon",
    "Houthi rebels (Yemen)*": "Yemen",
    "Indonesia rebels*": "Indonesia",
    "Khmer Rouge (Cambodia)*": "Cambodia",
    "Kurdistan Regional Government (Iraq)*": "Iraq",
    "LF (Lebanon)*": "Lebanon",
    "LRA (Uganda)*": "Uganda",
    "LTTE (Sri Lanka)*": "Sri Lanka",
    "Libya GNC": "Libya",
    "Libya HoR*": "Libya",
    "HoR (Libya)*": "Libya",
    "Congo": "Congo (Brazzaville)",
    "DR Congo": "Congo (Kinshasa)",
    "MNLF (Philippines)*": "Philippines",
    "MPLA (Portugal)*": "Portugal",
    "MTA (Myanmar)*": "Myanmar",
    "Micronesia": "Federated States of Micronesia",
    "Mujahedin (Afghanistan)*": "Afghanistan",
    "NLA (Macedonia)*": "North Macedonia",
    "NTC (Libya)*": "Libya",
    "Northern Alliance (Afghanistan)*": "Afghanistan",
    "Northern Cyprus": "Cyprus",
    "PAIGC (Portugal)*": "Portugal",
    "PIJ (Israel/Palestine)*": "Israel",
    "PKK (Turkiye)*": "Turkey",
    "PLO (Israel)*": "Israel",
    "PRC (Israel/Palestine)*": "Israel",
    "Pathet Lao (Laos)*": "Laos",
    "Provisional IRA (UK)*": "United Kingdom",
    "RPF (Rwanda)*": "Rwanda",
    "RUF (Sierra Leone)*": "United Kingdom",
    "SLA (Lebanon)*": "Lebanon",
    "SNA (Somalia)*": "Somalia",
    "SPLA (Sudan)*": "Sudan",
    "Southern rebels (Yemen)*": "Yemen",
    "Syria rebels*": "Syria",
    "Turkiye": "Turkey",
    "UAE": "United Arab Emirates",
    "UIC (Somalia)*": "Somalia",
    "UNITA (Angola)*": "Angola",
    "Ukraine Rebels*": "Ukraine",
    "United States": "United States of America",
    "United Wa State (Myanmar)*": "Myanmar",
    "Viet Minh (France)*": "France",
    "Viet Nam": "Vietnam",
    "ZAPU (Zimbabwe)*": "Zimbabwe",
    "GUNT (Chad)*": "Chad",
    "FAN (Chad)*": "Chad",
    "FMLN (El Salvador)*": "El Salvador",
    "Gambia": "The Gambia",
    "Lebanon Palestinian rebels*": "Lebanon",
    "Cote d'Ivoire": "Ivory Coast",
    "Bahamas": "The Bahamas",
    "FNLA (Angola)*": "Angola",
    "Cabo Verde": "Cape Verde",
    "Timor-Leste": "East Timor",
    "Saint Vincent": "Saint Vincent and the Grenadines",
    "Guinea-Bissau": "Guinea Bissau",
    "South Vietnam": "Vietnam",  # Saigon is now Ho Chi Minh City
    "Viet Cong (South Vietnam)*": "Vietnam",
    "Hamas (Palestine)*": "Palestine",
    "Soviet Union": "Russia",
    "NATO**": "Belgium",  # NATO headquarters in Brussels
    'European Union**': "Belgium",  # EU headquarters in Brussels
    "OSCE**": "Austria",  # secretariat in Vienna
    "Yemen Arab Republic (North Yemen)": "Yemen",  # same capital as Yemen (Sanaa)
    "North Yemen": "Yemen",  # same capital as Yemen (Sanaa)
    "Czechoslovakia": "Czechia",  # same capital as the modern Czech Republic (Prague)
    "Yugoslavia": "Serbia",  # same capital as Serbia (Belgrade)
    "East Germany (GDR)": "Germany",  # for large-scale flow maps, approximate East Berlin with Berlin
    "Western Sahara": "Morocco",  # largely under Moroccan occupation
}

exclude_flows = {
    "nan",
    "unknown rebel group*",
    "unknown recipient(s)",
    'unknown supplier(s)',
    "United Nations**",
    "Regional Security System**",
    "African Union**",
    '0.25',
    '3',
}

# %% [markdown]
# Even more exceptions!  These lat/longs were added by hand.

# %%
# (long, lat) coordinates for capitals of entities not included in the places shapefile.
# Several of these entities are countries that no longer exist.
extra_capitals = {
    "Biafra": ("Enugu", 7.5139, 6.4483),  # 1967 capital (now part of Nigeria)
    "Bosnia-Herzegovina": ("Sarajevo", 18.4131, 43.8563),
    "South Yemen": ("Aden", 45.0176, 12.7906),
    "Katanga": ("Lubumbashi", 27.5026, -11.6876),
    "South Sudan": ("Juba",  31.5825, 4.8539),
    "Palestine": ("East Jerusalem", 35.217018, 31.771959),
    "Aruba": ("Oranjestad", -70.0353, 12.5227),
}

# %% [markdown]
# ...and put into a format that's suitable for adding to the capitals list we're making.  Note the CRS (coordinate reference system) specified.

# %%
extra_capitals_gdf = gpd.GeoDataFrame(
    [
        {
            "adm0name": entity,
            "name": capital,
            "longitude": long,
            "latitude": lat,
            "geometry": Point(long, lat),
        }
        for entity, (capital, long, lat) in extra_capitals.items()
    ],
    crs="epsg:4326",
).set_index("adm0name")
extra_capitals_gdf
# Out:
#                               name  longitude   latitude  \
# adm0name
# Biafra                       Enugu   7.513900   6.448300
# Bosnia-Herzegovina        Sarajevo  18.413100  43.856300
# South Yemen                   Aden  45.017600  12.790600
# Katanga                 Lubumbashi  27.502600 -11.687600
# South Sudan                   Juba  31.582500   4.853900
# Palestine           East Jerusalem  35.217018  31.771959
# Aruba                   Oranjestad -70.035300  12.522700
#
#                                      geometry
# adm0name
# Biafra                  POINT (7.5139 6.4483)
# Bosnia-Herzegovina    POINT (18.4131 43.8563)
# South Yemen           POINT (45.0176 12.7906)
# Katanga              POINT (27.5026 -11.6876)
# South Sudan            POINT (31.5825 4.8539)
# Palestine           POINT (35.21702 31.77196)
# Aruba                POINT (-70.0353 12.5227)

# %% [markdown]
# Next we're going to read in a simple shapefile from a cartographic society that gives locations for major world cities and identifies which ones are capital cities.  Note even more special-case handling:  some countries have more than one capital!  (South Africa famously has three.)

# %%
places_gdf = gpd.read_file("https://naciscdn.org/naturalearth/110m/cultural/ne_110m_populated_places_simple.zip")
capitals_gdf = places_gdf[places_gdf["adm0cap"] == 1].set_index("adm0name")
# force each nation to have exactly one capital
capitals_gdf = capitals_gdf[~capitals_gdf["name"].isin(["Sucre", "Yamoussoukro", "Bloemfontein", "Pretoria"])][["name", "latitude", "longitude", "geometry"]]
capitals_gdf = gpd.GeoDataFrame(pd.concat([capitals_gdf, extra_capitals_gdf]), crs="epsg:4326")

# %%
capitals_gdf.tail(100)
# Out:
#                                        name   latitude   longitude  \
# adm0name
# Albania                              Tirana  41.327541   19.818883
# Armenia                             Yerevan  40.183097   44.511606
# Azerbaijan                             Baku  40.397218   49.860271
# Cambodia                         Phnom Penh  11.551976  104.914689
# Bolivia                              La Paz -16.496028  -68.151931
# Benin                               Cotonou   6.401954    2.518045
# Bulgaria                              Sofia  42.685295   23.314708
# Belarus                               Minsk  53.901923   27.564681
# Bhutan                              Thimphu  27.472986   89.639014
# Botswana                           Gaborone -24.646314   25.911948
# Australia                          Canberra -35.283029  149.129026
# Burkina Faso                    Ouagadougou  12.372262   -1.526670
# Bosnia and Herzegovina             Sarajevo  43.850022   18.383002
# Myanmar                           Naypyidaw  19.768503   96.116673
# Tonga                            Nuku'alofa -21.138512 -175.220565
# Somaliland                         Hargeisa   9.560022   44.065310
# Seychelles                         Victoria  -4.616632   55.449990
# Sao Tome and Principe              São Tomé   0.333402    6.733325
# Samoa                                  Apia -13.841545 -171.738642
# Malta                              Valletta  35.899733   14.514711
# Maldives                               Malé   4.166708   73.499948
# Israel                            Jerusalem  31.778408   35.206626
# Cape Verde                            Praia  14.916698  -23.516689
# The Bahamas                          Nassau  25.083390  -77.350044
# Cyprus                              Nicosia  35.166677   33.366635
# New Zealand                      Wellington -41.299988  174.783266
# Vietnam                               Hanoi  21.035273  105.848068
# Turkey                               Ankara  39.929184   32.862446
# Hungary                            Budapest  47.501952   19.081375
# Yemen                                 Sanaa  15.356679   44.204648
# Romania                           Bucharest  44.435318   26.098001
# Syria                              Damascus  33.501980   36.298050
# Portugal                             Lisbon  38.724669   -9.146812
# Sudan                              Khartoum  15.590024   32.532233
# Norway                                 Oslo  59.918636   10.748033
# Poland                               Warsaw  52.251947   20.998054
# North Korea                       Pyongyang  39.021385  125.752745
# Tanzania                      Dar es Salaam  -6.798067   39.266396
# Ireland                              Dublin  53.335007   -6.250852
# Liberia                            Monrovia   6.314582  -10.799660
# Malaysia                       Kuala Lumpur   3.168612  101.698037
# Cuba                                 Havana  23.133905  -82.366128
# Czechia                              Prague  50.085283   14.464034
# Kuwait                          Kuwait City  29.371664   47.976355
# Dominican Republic            Santo Domingo  18.472019  -69.902031
# Ghana                                 Accra   5.551981   -0.218662
# Libya                               Tripoli  32.892500   13.180012
# Finland                            Helsinki  60.177509   24.932181
# Denmark                           København  55.680510   12.561540
# Ivory Coast                         Abidjan   5.321943   -4.041994
# Brazil                             Brasília -15.781394  -47.917998
# Belgium                            Brussels  50.835263    4.331371
# Bangladesh                            Dhaka  23.725006   90.406634
# Angola                               Luanda  -8.836340   13.232481
# Algeria                             Algiers  36.765011    3.048607
# Venezuela                           Caracas  10.502944  -66.918983
# Ukraine                                Kyiv  50.435313   30.514682
# Uzbekistan                         Tashkent  41.313648   69.292987
# Spain                                Madrid  40.401972   -3.685298
# Sweden                            Stockholm  59.352706   18.095389
# Thailand                            Bangkok  13.751945  100.514699
# Peru                                   Lima -12.046067  -77.052008
# Senegal                               Dakar  14.717778  -17.475076
# Netherlands                       Amsterdam  52.351915    4.914694
# South Korea                           Seoul  37.568295  126.997785
# Philippines                          Manila  14.606105  120.980271
# Germany                              Berlin  52.523765   13.399603
# Congo (Kinshasa)                   Kinshasa  -4.327778   15.313026
# India                             New Delhi  28.600023   77.199980
# Greece                               Athens  37.985272   23.731375
# Iraq                                Baghdad  33.340594   44.391923
# Ethiopia                        Addis Ababa   9.035256   38.698059
# Iran                                 Tehran  35.673889   51.422398
# Argentina                      Buenos Aires -34.600556  -58.399477
# Afghanistan                           Kabul  34.518636   69.181314
# Austria                              Vienna  48.201961   16.364693
# Taiwan                               Taipei  25.035833  121.568333
# United States of America  Washington,  D.C.  38.901495  -77.011364
# United Kingdom                       London  51.501941   -0.118668
# Saudi Arabia                         Riyadh  24.642779   46.770796
# South Africa                      Cape Town -33.918065   18.433042
# Russia                               Moscow  55.754110   37.613577
# Mexico                          Mexico City  19.444388  -99.132934
# Italy                                  Rome  41.897902   12.481313
# China                               Beijing  39.930838  116.386340
# Kenya                               Nairobi  -1.281401   36.814711
# Indonesia                           Jakarta  -6.172472  106.827492
# Colombia                             Bogota   4.598369  -74.085290
# Egypt                                 Cairo  30.051906   31.248022
# Japan                                 Tokyo  35.686963  139.749462
# France                                Paris  48.868639    2.331390
# Chile                              Santiago -33.448068  -70.668987
# Singapore                         Singapore   1.294979  103.853875
# Biafra                                Enugu   6.448300    7.513900
# Bosnia-Herzegovina                 Sarajevo  43.856300   18.413100
# South Yemen                            Aden  12.790600   45.017600
# Katanga                          Lubumbashi -11.687600   27.502600
# South Sudan                            Juba   4.853900   31.582500
# Palestine                    East Jerusalem  31.771959   35.217018
# Aruba                            Oranjestad  12.522700  -70.035300
#
#                                               geometry
# adm0name
# Albania                      POINT (19.81888 41.32754)
# Armenia                       POINT (44.51161 40.1831)
# Azerbaijan                   POINT (49.86027 40.39722)
# Cambodia                    POINT (104.91469 11.55198)
# Bolivia                    POINT (-68.15193 -16.49603)
# Benin                          POINT (2.40435 6.36298)
# Bulgaria                      POINT (23.31471 42.6853)
# Belarus                      POINT (27.56468 53.90192)
# Bhutan                       POINT (89.63901 27.47299)
# Botswana                    POINT (25.91195 -24.64631)
# Australia                  POINT (149.12903 -35.28303)
# Burkina Faso                 POINT (-1.52667 12.37226)
# Bosnia and Herzegovina         POINT (18.383 43.85002)
# Myanmar                       POINT (96.11667 19.7685)
# Tonga                     POINT (-175.22056 -21.13851)
# Somaliland                    POINT (44.06531 9.56002)
# Seychelles                   POINT (55.44999 -4.61663)
# Sao Tome and Principe          POINT (6.72965 0.33747)
# Samoa                      POINT (-171.7686 -13.83571)
# Malta                        POINT (14.51471 35.89973)
# Maldives                       POINT (73.5089 4.17204)
# Israel                       POINT (35.20663 31.77841)
# Cape Verde                   POINT (-23.51669 14.9167)
# The Bahamas                 POINT (-77.35004 25.08339)
# Cyprus                       POINT (33.36663 35.16668)
# New Zealand                 POINT (174.7772 -41.29207)
# Vietnam                     POINT (105.84807 21.03527)
# Turkey                       POINT (32.86245 39.92918)
# Hungary                      POINT (19.08137 47.50195)
# Yemen                        POINT (44.20465 15.35668)
# Romania                        POINT (26.098 44.43532)
# Syria                        POINT (36.29805 33.50198)
# Portugal                     POINT (-9.14681 38.72467)
# Sudan                        POINT (32.53223 15.59002)
# Norway                       POINT (10.74803 59.91864)
# Poland                       POINT (21.00535 52.23087)
# North Korea                 POINT (125.75274 39.02138)
# Tanzania                      POINT (39.2664 -6.79807)
# Ireland                      POINT (-6.25698 53.34673)
# Liberia                      POINT (-10.79966 6.31458)
# Malaysia                       POINT (101.6887 3.1398)
# Cuba                         POINT (-82.36613 23.1339)
# Czechia                      POINT (14.42294 50.08697)
# Kuwait                       POINT (47.97636 29.37166)
# Dominican Republic          POINT (-69.92974 18.47075)
# Ghana                         POINT (-0.21866 5.55198)
# Libya                         POINT (13.18001 32.8925)
# Finland                       POINT (24.93246 60.1638)
# Denmark                      POINT (12.56154 55.68051)
# Ivory Coast                   POINT (-4.02021 5.32313)
# Brazil                       POINT (-47.918 -15.78139)
# Belgium                       POINT (4.33137 50.83526)
# Bangladesh                   POINT (90.40663 23.72501)
# Angola                       POINT (13.23248 -8.83634)
# Algeria                       POINT (3.04861 36.76501)
# Venezuela                   POINT (-66.91898 10.50294)
# Ukraine                      POINT (30.51468 50.43531)
# Uzbekistan                   POINT (69.26882 41.30383)
# Spain                         POINT (-3.6853 40.40197)
# Sweden                        POINT (18.0663 59.32413)
# Thailand                     POINT (100.5147 13.75195)
# Peru                       POINT (-77.05201 -12.04607)
# Senegal                     POINT (-17.47508 14.71778)
# Netherlands                   POINT (4.91469 52.35191)
# South Korea                  POINT (126.99779 37.5683)
# Philippines                  POINT (120.98027 14.6061)
# Germany                       POINT (13.3996 52.52376)
# Congo (Kinshasa)             POINT (15.31303 -4.32778)
# India                        POINT (77.19998 28.60002)
# Greece                       POINT (23.73138 37.98527)
# Iraq                         POINT (44.39192 33.34059)
# Ethiopia                      POINT (38.69806 9.03526)
# Iran                          POINT (51.4224 35.67389)
# Argentina                  POINT (-58.43251 -34.61071)
# Afghanistan                  POINT (69.18131 34.51864)
# Austria                      POINT (16.36469 48.20196)
# Taiwan                      POINT (121.56833 25.03583)
# United States of America     POINT (-77.01136 38.9015)
# United Kingdom               POINT (-0.11867 51.50194)
# Saudi Arabia                  POINT (46.72049 24.6345)
# South Africa                POINT (18.43304 -33.91807)
# Russia                       POINT (37.61358 55.75411)
# Mexico                      POINT (-99.13293 19.44439)
# Italy                         POINT (12.48131 41.8979)
# China                        POINT (116.3942 39.90172)
# Kenya                         POINT (36.81471 -1.2814)
# Indonesia                   POINT (106.82749 -6.17247)
# Colombia                     POINT (-74.08529 4.59837)
# Egypt                        POINT (31.24802 30.05191)
# Japan                       POINT (139.74946 35.68696)
# France                        POINT (2.35299 48.85809)
# Chile                       POINT (-70.6505 -33.44021)
# Singapore                    POINT (103.85387 1.29498)
# Biafra                           POINT (7.5139 6.4483)
# Bosnia-Herzegovina             POINT (18.4131 43.8563)
# South Yemen                    POINT (45.0176 12.7906)
# Katanga                       POINT (27.5026 -11.6876)
# South Sudan                     POINT (31.5825 4.8539)
# Palestine                    POINT (35.21702 31.77196)
# Aruba                         POINT (-70.0353 12.5227)

# %% [markdown]
# Hopefully this dataset gives you many ideas of things you could analyze.
#
# Here are just a few...
# * Study arms flows connected to a protracted conflict (e.g., Israel–Palestine)
# * Pick a small window of time, like 1-2 years, and do a deeper look at that snapshot.
# * The USSR collapsed circa 1991.  Do you see an immediate impact on arms flows?
# * Consider second-hand arms sales.  How does weaponry "trickle down" from rich exporters to first and then second recipients.
# * How does the popularity and regionality of a particular weapon (e.g., the Mi-17) change over time?

# %% [markdown]
# # Building a graph

# %% [markdown]
# To make a visual that shows the movement, a natural data object is a **graph**, in the sense of discrete mathematics.  A graph is made up of vertices (also called nodes), with some of them connected by edges.  The edges can be weighted, and can have a direction.  So a flow can be represented as a weighted directed edge from vertex $v$ to vertex $w$.

# %% [markdown]
# We'll set this up with a dataframe giving only a limited number of attributes per state, then a secondary dataframe grouping by year.

# %%
flowmap_arms_df = arms_df[~arms_df["Supplier"].isin(exclude_flows) & ~arms_df["Recipient"].isin(exclude_flows)].rename(
    columns={
        "Year of order": "order_year",
        "Recipient": "recipient",
        "Supplier": "supplier",
        "SIPRI TIV for total order": "order_sipri_tiv"
    }
)
flowmap_arms_df["order_year"] = flowmap_arms_df["order_year"].astype(int)
flowmap_arms_df = flowmap_arms_df[flowmap_arms_df["order_year"] >= 1950]

# %%
orders_by_year_df = flowmap_arms_df.groupby(["order_year", "recipient", "supplier"]).sum()["order_sipri_tiv"]
orders_by_year_df
# Out:
# order_year  recipient      supplier
# 1950        Argentina      United States     135.51
#             Australia      United Kingdom    337.68
#                            United States       0.60
#             Belgium        United Kingdom     78.00
#                            United States     763.02
#                                               ...
# 2025        United States  Sweden              0.00
#             Uruguay        Brazil              0.56
#                            Italy               2.00
#             Uzbekistan     Turkiye             0.00
#             Viet Nam       South Korea       150.00
# Name: order_sipri_tiv, Length: 15656, dtype: float64

# %% [markdown]
# ## Example
# Let's visualize arms flows to and from the U.S. in a particular year by constructing a graph.

# %%
year = 1980
country = "United States"

# %%
filtered_orders_df = orders_by_year_df[year].reset_index()
filtered_orders_df = filtered_orders_df[
    (filtered_orders_df["recipient"] == "United States")
    | (filtered_orders_df["supplier"] == "United States")
]
filtered_orders_df.head(10)
# Out:
#      recipient       supplier  order_sipri_tiv
# 13   Argentina  United States            46.50
# 17   Australia  United States           481.60
# 18     Austria  United States           105.00
# 21  Bangladesh  United States            14.80
# 25     Bolivia  United States             5.64
# 31      Brunei  United States             1.40
# 36      Canada  United States          4335.26
# 45       Chile  United States            45.20
# 50    Colombia  United States            42.92
# 53  Costa Rica  United States             0.44

# %% [markdown]
# We imported NetworkX above as `nx`.  Our graph will have directed edges FROM the supplier TO the recipient of an arms shipment.

# %%
orders_graph = nx.DiGraph()

for _, row in filtered_orders_df.iterrows():
    orders_graph.add_edge(
        row.supplier,
        row.recipient,
        weight=row.order_sipri_tiv,
    )

# %% [markdown]
# Where did the U.S. send arms that year?  (or receive from!)

# %%
orders_graph.edges
# Out:
# OutEdgeView([('United States', 'Argentina'), ('United States', 'Australia'), ('United States', 'Austria'), ('United States', 'Bangladesh'), ('United States', 'Bolivia'), ('United States', 'Brunei'), ('United States', 'Canada'), ('United States', 'Chile'), ('United States', 'Colombia'), ('United States', 'Costa Rica'), ('United States', 'Denmark'), ('United States', 'Dominican Republic'), ('United States', 'Ecuador'), ('United States', 'Egypt'), ('United States', 'El Salvador'), ('United States', 'Finland'), ('United States', 'Gabon'), ('United States', 'Germany'), ('United States', 'Greece'), ('United States', 'Guatemala'), ('United States', 'Honduras'), ('United States', 'Indonesia'), ('United States', 'Israel'), ('United States', 'Italy'), ('United States', 'Jamaica'), ('United States', 'Japan'), ('United States', 'Jordan'), ('United States', 'Kenya'), ('United States', 'Malaysia'), ('United States', 'Mauritania'), ('United States', 'Morocco'), ('United States', 'Myanmar'), ('United States', 'NATO**'), ('United States', 'Netherlands'), ('United States', 'New Zealand'), ('United States', 'Oman'), ('United States', 'Pakistan'), ('United States', 'Paraguay'), ('United States', 'Peru'), ('United States', 'Philippines'), ('United States', 'Portugal'), ('United States', 'Saudi Arabia'), ('United States', 'Singapore'), ('United States', 'South Korea'), ('United States', 'Spain'), ('United States', 'Sudan'), ('United States', 'Sweden'), ('United States', 'Taiwan'), ('United States', 'Thailand'), ('United States', 'Tunisia'), ('United States', 'Turkiye'), ('United States', 'United Arab Emirates'), ('United States', 'United Kingdom'), ('United States', 'Uruguay'), ('United States', 'Venezuela'), ('United Kingdom', 'United States')])

# %% [markdown]
# Next we'll make a static map.  You can play around with thickness and color of the directed edges.

# %%
def cast_point(p):
    return (p.xy[0][0], p.xy[1][0])

# %%
fig, ax = plt.subplots(figsize=(20, 40))
ax.axis("off")
places_gdf.plot(ax=ax, edgecolor="0.1", linewidth=1, color="#e1f1fd", alpha=0.5)

pos = dict(capitals_gdf.geometry)

for edge in orders_graph.edges(data='weight'):
    if edge[0] in exclude_flows or edge[1] in exclude_flows:
        continue

    edge_pos = {
        edge[0]: cast_point(pos[capitals_map.get(edge[0], edge[0])]),
        edge[1]: cast_point(pos[capitals_map.get(edge[1], edge[1])]),
    }
    nx.draw_networkx_edges(orders_graph, edge_pos, edgelist=[edge], width=0.001 * edge[2], ax=ax, edge_color="blue")

# %% [markdown]
# ## FlowmapBlue

# %% [markdown]
# This line will pop up a dialog asking for permission to generate Google Sheets credentials using your Google login.  If you're doing this in Colab, it should be particularly seamless.

# %%
flowmap_locations_df = pd.DataFrame(
    [
        {
            "id": loc,
            "name": loc,
            "lat": capitals_gdf.loc[capitals_map.get(loc, loc), "latitude"],
            "lon": capitals_gdf.loc[capitals_map.get(loc, loc), "longitude"],
        }
        for loc in set(flowmap_arms_df["supplier"]) | set(flowmap_arms_df["recipient"])
    ]
)
flowmap_locations_df.head(5)
# Out:
#                id            name        lat        lon
# 0          Cyprus          Cyprus  35.166677  33.366635
# 1        Bulgaria        Bulgaria  42.685295  23.314708
# 2   Guinea-Bissau   Guinea-Bissau  11.865024 -15.598361
# 3  MTA (Myanmar)*  MTA (Myanmar)*  19.768503  96.116673
# 4   United States   United States  38.901495 -77.011364

# %% [markdown]
# If you don't want to go through the whole Google permissions thing, read this [Medium article](https://medium.com/@a.marenkov/how-to-get-credentials-for-google-sheets-456b7e88c430) for info about getting credentials.

# %%
sheet_creds = google_sheets_credentials()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-67-1383826990.py in <cell line: 0>()
# ----> 1 sheet_creds = google_sheets_credentials()
#
# /usr/local/lib/python3.11/dist-packages/pubpol2130/flows.py in google_sheets_credentials()
#      23             raise ex
#      24
# ---> 25     auth.authenticate_user()
#      26     creds, _ = default()
#      27     return creds
#
# /usr/local/lib/python3.11/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
flow_sheet = generate_flow_sheet(
    sheet_creds=sheet_creds,
    locations_df=flowmap_locations_df,
    created_by_name="",  # YOUR NAME HERE
    created_by_email="", # YOUR EMAIL HERE
    data_source_name="SIPRI Arms Transfers Database",
    data_source_url="https://www.sipri.org/databases/armstransfers",
    incoming_tooltip="Inbound arms transfers (TIV)",
    outgoing_tooltip="Outbound arms transfers (TIV)",
    flow_tooltip="Arms transfer (TIV)",
    total_unit="TIVs",
    sheet_title="PUBPOL 2130: SIPRI arms transfers (orders over time)",
    flow_title="SIPRI Arms Transfers Database: orders over time",
    flows={
        f"Year: {year}": year_df.reset_index().rename(columns={
            "supplier": "origin",
            "recipient": "dest",
            "order_sipri_tiv": "count",
        })
        for year, year_df in orders_by_year_df.groupby(level=0)
    }
)

# %%
print(flow_sheet.url)

# %%
print(f"https://www.flowmap.blue/{flow_sheet.url.split('/')[-1]}")
